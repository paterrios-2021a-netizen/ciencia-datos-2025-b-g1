# %% [markdown]
# **📈Análisis del Rendimiento Académico**
#
# PAULA ANDREA TERRIOS OSSA - Parcial II
#
# En este notebook se analizan las calificaciones de los estudiantes en diferentes materias y cortes académicos.
#
# **Caso:** La mejora total en el promedio de cada materia desde el Corte 1 hasta el Corte 3 y cuál de ellas presentó el mayor crecimiento en el rendimiento académico del grupo

# %%
# Out:
#         Materia   Estudiante  Corte  Parcial  Actividades  Certificacion  \
# 0   Matemáticas   Ana Torres      1      3.2          2.8            3.5
# 1   Matemáticas   Ana Torres      2      2.9          3.0            3.2
# 2   Matemáticas   Ana Torres      3      3.5          3.2            3.8
# 3   Matemáticas   Luis Pérez      1      2.5          2.0            2.8
# 4   Matemáticas   Luis Pérez      2      2.8          2.5            2.9
# 5   Matemáticas   Luis Pérez      3      3.2          2.9            3.0
# 6   Matemáticas  María Gómez      1      4.0          3.8            4.2
# 7   Matemáticas  María Gómez      2      4.2          4.0            4.3
# 8   Matemáticas  María Gómez      3      4.5          4.3            4.6
# 9   Matemáticas  Carlos Ruiz      1      3.5          3.2            3.6
# 10  Matemáticas  Carlos Ruiz      2      3.0          2.9            3.2
# 11  Matemáticas  Carlos Ruiz      3      2.5          2.3            2.7
# ...

# %%
# Out:
#         Materia   Estudiante  Corte  Parcial  Actividades  Certificacion  \
# 0   Matemáticas   Ana Torres      1      3.2          2.8            3.5
# 1   Matemáticas   Ana Torres      2      2.9          3.0            3.2
# 2   Matemáticas   Ana Torres      3      3.5          3.2            3.8
# 3   Matemáticas   Luis Pérez      1      2.5          2.0            2.8
# 4   Matemáticas   Luis Pérez      2      2.8          2.5            2.9
# 5   Matemáticas   Luis Pérez      3      3.2          2.9            3.0
# 6   Matemáticas  María Gómez      1      4.0          3.8            4.2
# 7   Matemáticas  María Gómez      2      4.2          4.0            4.3
# 8   Matemáticas  María Gómez      3      4.5          4.3            4.6
# 9   Matemáticas  Carlos Ruiz      1      3.5          3.2            3.6
# 10  Matemáticas  Carlos Ruiz      2      3.0          2.9            3.2
# 11  Matemáticas  Carlos Ruiz      3      2.5          2.3            2.7
# ...

# %%
# Out:
# Corte
# 1    3.568
# 2    3.442
# 3    3.516
# Name: Nota Final, dtype: float64

# %%
average_grades_corte1 = df[df['Corte'] == 1].groupby('Materia')['Nota Final'].mean()
average_grades_corte3 = df[df['Corte'] == 3].groupby('Materia')['Nota Final'].mean()

improvement_by_subject = average_grades_corte3 - average_grades_corte1

print("Mejora total en el promedio de cada materia (Corte 3 - Corte 1):")
display(improvement_by_subject)

best_subject = improvement_by_subject.idxmax()
max_improvement = improvement_by_subject.max()

print(f"\nLa materia con el mayor crecimiento en el rendimiento académico del grupo es: {best_subject} con una mejora de {max_improvement:.2f}")
# Out:
# Mejora total en el promedio de cada materia (Corte 3 - Corte 1):
# Materia
# Historia      -0.178
# Matemáticas    0.074
# Name: Nota Final, dtype: float64
# La materia con el mayor crecimiento en el rendimiento académico del grupo es: Matemáticas con una mejora de 0.07
